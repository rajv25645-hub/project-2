# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\asus\Downloads\spotify_churn_dataset.csv")
df.head()
# Out:
#    user_id  gender  age country subscription_type  listening_time  \
# 0        1  Female   54      CA              Free              26
# 1        2   Other   33      DE            Family             141
# 2        3    Male   38      AU           Premium             199
# 3        4  Female   22      CA           Student              36
# 4        5   Other   29      US            Family             250
#
#    songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 0                    23       0.20     Desktop                     31
# 1                    62       0.34         Web                      0
# 2                    38       0.04      Mobile                      0
# 3                     2       0.31      Mobile                      0
# 4                    57       0.36      Mobile                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# 2                  1           1
# ...

# %%
df.isnull().sum()
# Out:
# user_id                  0
# gender                   0
# age                      0
# country                  0
# subscription_type        0
# listening_time           0
# songs_played_per_day     0
# skip_rate                0
# device_type              0
# ads_listened_per_week    0
# offline_listening        0
# is_churned               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                8000 non-null   int64
#  1   gender                 8000 non-null   object
#  2   age                    8000 non-null   int64
#  3   country                8000 non-null   object
#  4   subscription_type      8000 non-null   object
#  5   listening_time         8000 non-null   int64
#  6   songs_played_per_day   8000 non-null   int64
#  7   skip_rate              8000 non-null   float64
#  8   device_type            8000 non-null   object
#  9   ads_listened_per_week  8000 non-null   int64
#  10  offline_listening      8000 non-null   int64
#  11  is_churned             8000 non-null   int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 750.1+ KB

# %%
df=df.drop(columns=["user_id","country"])
df.head()
# Out:
#    gender  age subscription_type  listening_time  songs_played_per_day  \
# 0  Female   54              Free              26                    23
# 1   Other   33            Family             141                    62
# 2    Male   38           Premium             199                    38
# 3  Female   22           Student              36                     2
# 4   Other   29            Family             250                    57
#
#    skip_rate device_type  ads_listened_per_week  offline_listening  is_churned
# 0       0.20     Desktop                     31                  0           1
# 1       0.34         Web                      0                  1           0
# 2       0.04      Mobile                      0                  1           1
# 3       0.31      Mobile                      0                  1           0
# 4       0.36      Mobile                      0                  1           1

# %%
f=df[(df["offline_listening"]==0)].shape[0]
f
# Out:
# 2018

# %%
df["offline_listening"].value_counts()
# Out:
# offline_listening
# 1    5982
# 0    2018
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encode=OneHotEncoder()
x=encode.fit_transform(df[["gender"]]).toarray()

# %%
encode2=OneHotEncoder()
y=encode2.fit_transform(df[["device_type"]]).toarray()

# %%
encoded_df=pd.DataFrame(x,columns=encode.get_feature_names_out())

# %%
encoded_df1=pd.DataFrame(y,columns=encode2.get_feature_names_out())

# %%
final_df=pd.concat([df,encoded_df,encoded_df1],axis=1)

# %%
df=final_df.drop(columns=["gender","device_type"])
df.head()
# Out:
#    age subscription_type  listening_time  songs_played_per_day  skip_rate  \
# 0   54              Free              26                    23       0.20
# 1   33            Family             141                    62       0.34
# 2   38           Premium             199                    38       0.04
# 3   22           Student              36                     2       0.31
# 4   29            Family             250                    57       0.36
#
#    ads_listened_per_week  offline_listening  is_churned  gender_Female  \
# 0                     31                  0           1            1.0
# 1                      0                  1           0            0.0
# 2                      0                  1           1            0.0
# 3                      0                  1           0            1.0
# 4                      0                  1           1            0.0
#
#    gender_Male  gender_Other  device_type_Desktop  device_type_Mobile  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
df["subscription_type"]=encoder.fit_transform(df["subscription_type"])

# %%
df.head()
# Out:
#    age  subscription_type  listening_time  songs_played_per_day  skip_rate  \
# 0   54                  1              26                    23       0.20
# 1   33                  0             141                    62       0.34
# 2   38                  2             199                    38       0.04
# 3   22                  3              36                     2       0.31
# 4   29                  0             250                    57       0.36
#
#    ads_listened_per_week  offline_listening  is_churned  gender_Female  \
# 0                     31                  0           1            1.0
# 1                      0                  1           0            0.0
# 2                      0                  1           1            0.0
# 3                      0                  1           0            1.0
# 4                      0                  1           1            0.0
#
#    gender_Male  gender_Other  device_type_Desktop  device_type_Mobile  \
# ...

# %%
x=df.drop(columns="is_churned")

# %%
y=df["is_churned"]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()
x=scale.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier=LogisticRegression()
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_pred,y_test))
# Out:
# 0.75

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(x_test)

# %%
print(accuracy_score(y_pred,y_test))
# Out:
# 0.7425

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_pred,y_test))
# Out:
# [[1178  390]
#  [  22   10]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.75      0.85      1568
#            1       0.03      0.31      0.05        32
#
#     accuracy                           0.74      1600
#    macro avg       0.50      0.53      0.45      1600
# weighted avg       0.96      0.74      0.84      1600
